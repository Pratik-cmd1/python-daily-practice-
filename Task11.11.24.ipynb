# %% [markdown]
# # Car Rental System Case Study - conditional statement case study

# %% [markdown]
# #####                                                                                    ---PRATIK GAIKWAD

# %% [markdown]
# ### Task 1: Define Rental Rates Based on Car Type

# %% [raw]
# Objective: Set different rental rates for car types (Economy, Standard, Luxury) using conditional statements.
# 1.Prompt the user to enter a car type (Economy, Standard, or Luxury).
# 2. assign a daily rental rate:
#    - Economy: $50/day
#    - Standard: $75/day
#    - Luxury: $100/day
# 3. If an invalid car type is entered, display an error message and exit.
# Expected Output: The daily rental rate based on the car type

# %%
cartype=input("Enter car type form it (Economy, Standard, or Luxury) : ")
Economy= 50
Standard= 75
Luxury= 100

if (cartype=="Economy"):
    print(f"rental rates for car type : Economy is {Economy} ")
elif (cartype=="Standard"):
    print(f"rental rates for car type : Standard is {Standard} ")
elif (cartype=="Luxury"):
    print(f"rental rates for car type : Luxury is {Luxury} ")
else :
    print("error : not entered valid Car Type\n EXIT ")
# Out:
# Enter car type form it (Economy, Standard, or Luxury) :  Luxury
# rental rates for car type : Luxury is 100

# %% [markdown]
# ### Task 2: Calculate Rental Duration Fee

# %% [raw]
# Objective: Calculate the base rental fee by multiplying the daily rate by the number of rental days.
# 1. Prompt the user to enter the number of rental days.
# 2. Validate the input as a positive integer; otherwise, display an error and exit.
# 3. Calculate the base_fee as the product of the daily rental rate and rental days.
# Expected Output: The base_fee based on the rental days and car type

# %%
cartype=input("Enter car type form it (Economy, Standard, or Luxury) : ")
Economy= 50
Standard=75
Luxury= 100
days=input("Enter the number of rental days: ")
days=int(days)
if (days>0):
    print(f"you have entered {days} Days......! ")
    if (cartype=="Economy"):
        print(f"rental rates for car type : Economy is ${Economy}/day  ")
        base_fee=50*days
        print(f"the base fee as per car type of the daily rental rate and rental days is : ${base_fee}")
    elif (cartype=="Standard"):
        print(f"rental rates for car type : Standard is ${Standard}/day ")
        base_fee=75*days
        print(f"the base fee as per car type of the daily rental rate and rental days is : ${base_fee}")
    elif (cartype=="Luxury"):
        print(f"rental rates for car type : Luxury is ${Luxury}/day ")
        base_fee=100*days
        print(f"the base fee as per car type of the daily rental rate and rental days is : ${base_fee}")
else :
    print(f" please enter valid days you have entered : {days} \n EXIT")
# Out:
# Enter car type form it (Economy, Standard, or Luxury) :  Luxury
# Enter the number of rental days:  10
# you have entered 10 Days......!
# rental rates for car type : Luxury is $100/day
# the base fee as per car type of the daily rental rate and rental days is : $1000

# %% [markdown]
# ### Task 3: Apply Membership Discount

# %% [raw]
# Objective: Adjust the base_fee by applying a membership discount if applicable.
# Steps:
# 1. Prompt the user to enter their membership type (Premium, Standard, or none).
# 2. Use conditional statements to determine the discount rate:
#    - Premium: 15% discount
#    - Standard: 10% discount
#    - None: No discount
# 3. If the membership type is invalid, display an error and exit.
# 4. Calculate the discount amount and subtract it from the base_fee.
# Expected Output: The adjusted fee after the membership discount.

# %%
cartype=input("Enter car type form it (Economy, Standard, or Luxury) : ")
Economy= 50
Standard=75
Luxury= 100
days=input("Enter the number of rental days: ")
mtype=input("Enter your membership type (Premium, Standard, or none) ")

days=int(days)
if (days>0):
    print(f"you have entered {days} Days......! ")
    if (cartype=="Economy"):
        print(f"rental rates for car type : Economy is ${Economy}/day  ")
        base_fee=50*days
        if (mtype=="Premium"):
            discount=base_fee*(1 - 0.15)
            print(f"rantal days is : {days} ")
            print(f"total price without discount is {base_fee} \nbut you are premium user so discount is 15 % \n total price including discount :{discount}  ")
        elif (mtype=="Standard"):
            discount=base_fee*(1 - 0.10)
            print(f"rantal days is : {days} ")
            print(f"total price without discount is {base_fee} \nbut you are premium user so discount is 10 % \n total price including discount :{discount}  ")
        else :
            discount=base_fee
            print(f"rantal days is : {days} ")
            print(f"total price without discount is {base_fee} \nbut you are None membership user so no discount for you sorry....! \n total price :{discount}  ")

    elif (cartype=="Standard"):
        print(f"rental rates for car type : Standard is ${Standard}/day ")
        base_fee=75*days


        if (mtype=="Premium"):
            discount=base_fee*(1 - 0.15)
            print(f"rantal days is : {days} ")
            print(f"total price without discount is {base_fee} \nbut you are premium user so discount is 15 % \n total price including discount :{discount}  ")
        elif (mtype=="Standard"):
            discount=base_fee*(1 - 0.10)
            print(f"rantal days is : {days} ")
            print(f"total price without discount is {base_fee} \nbut you are premium user so discount is 10 % \n total price including discount :{discount}  ")
        else :
            discount=base_fee
            print(f"rantal days is : {days} ")
            print(f"total price without discount is {base_fee} \nbut you are None membership user so no discount for you sorry....! \n total price :{discount}  ")

    elif (cartype=="Luxury"):
        print(f"rental rates for car type : Luxury is ${Luxury}/day ")
        base_fee=100*days
        if (mtype=="Premium"):
            discount=base_fee*(1 - 0.15)
            print(f"rantal days is : {days} ")
            print(f"total price without discount is {base_fee} \nbut you are premium user so discount is 15 % \n total price including discount :{discount}  ")
        elif (mtype=="Standard"):
            discount=base_fee*(1 - 0.10)
            print(f"rantal days is : {days} ")
            print(f"total price without discount is {base_fee} \nbut you are premium user so discount is 10 % \n total price including discount :{discount}  ")
        else :
            discount=base_fee
            print(f"rantal days is : {days} ")
            print(f"total price without discount is {base_fee} \nbut you are None membership user so no discount for you sorry....! \n total price :{discount}  ")

else :
    print(f" please enter valid days you have entered : {days} \n or check your membership type \n EXIT ")
# Out:
# Enter car type form it (Economy, Standard, or Luxury) :  Luxury
# Enter the number of rental days:  3
# Enter your membership type (Premium, Standard, or none)  Standard
# you have entered 3 Days......!
# rental rates for car type : Luxury is $100/day
# rantal days is : 3
# total price without discount is 300
# but you are premium user so discount is 10 %
#  total price including discount :270.0

# %% [markdown]
# ### Task 4: Add Optional Services

# %% [raw]
# Objective: Calculate additional charges for optional services (Insurance and GPS).
# Steps:
# 1. Prompt the user to indicate if they want to add Insurance (yes or no).
#    - If 'yes', calculate Insurance fee at $20 per day.
# 2. Prompt the user to indicate if they want to add GPS (yes or no).
#    - If 'yes', calculate GPS fee at $5 per day.
# 3. Use conditional statements to add the appropriate fees based on user choices.
# Expected Output: The additional services fee based on selected options.

# %%
print("******************WEL-COME**********************\n\n")
cartype=input("Enter car type form it (Economy, Standard, or Luxury) : ")
Economy= 50
Standard=75
Luxury= 100
days=input("Enter the number of rental days: ")
mtype=input("Enter your membership type (Premium, Standard, or none) ")
print("optional services (Insurance and GPS)")
Insurance=input("Insurance fee at $20 per day (yes or no): ")
GPS=input("GPS fee at $5 per day (yes or no): ")
print("\n\n******************THANK-YOU**********************")
print("\n")

days=int(days)
if (days>0):

# if car type is Economy  
    if (cartype=="Economy"):
        print(f"rental rates for car type : Economy is ${Economy}/day  ")
        base_fee=50*days
# car type is Economy and membership is Premium
        if (mtype=="Premium"): 
            if (Insurance=="yes")and (GPS=="yes"):
                addprice=(20*days)+(5*days)
                total_price=base_fee+addprice
                discount=total_price*(1 - 0.15)
                print(f"rantal days is : {days} ")
                print(f"optional service charge is : {addprice}\ntotal price without discount is : {total_price}")
                print(f"but you are premium user so discount is 15 % \n\n total price including discount :{discount}  ")
            elif(Insurance=="yes")and (GPS=="no"):
                addprice=(20*days)
                total_price=base_fee+addprice
                discount=total_price*(1 - 0.15)
                print(f"rantal days is : {days} ")
                print(f"optional service charge is : {addprice}\ntotal price without discount is : {total_price}")
                print(f"but you are premium user so discount is 15 % \n\n total price including discount :{discount}  ")
            elif(Insurance=="no")and (GPS=="yes"):
                addprice=(5*days)
                total_price=base_fee+addprice
                discount=total_price*(1 - 0.15)
                print(f"rantal days is : {days} ")
                print(f"optional service charge is : {addprice}\ntotal price without discount is : {total_price}")
                print(f"but you are premium user so discount is 15 % \n\n total price including discount :{discount}  ")   
            elif(Insurance=="no")and (GPS=="no"):
                addprice=0
                total_price=base_fee+addprice
                discount=total_price*(1 - 0.15)
                print(f"rantal days is : {days} ")
                print(f"optional service charge is : {addprice}\ntotal price without discount is : {total_price}")
                print(f"but you are premium user so discount is 15 % \n\n total price including discount :{discount}  ")  
            else:
                print("Please enter valid Optional service.........!")  

# car type is Economy and membership is standard
        elif (mtype=="Standard"):         
            if (Insurance=="yes")and (GPS=="yes"):
                addprice=(20*days)+(5*days)
                total_price=base_fee+addprice
                discount=total_price*(1 - 0.10)
                print(f"rantal days is : {days} ")
                print(f"optional service charge is : {addprice}\ntotal price without discount is : {total_price}")
                print(f'''but you are "Standard" user so discount is 10 % \n\n total price including discount :{discount}  ''')
            elif(Insurance=="yes")and (GPS=="no"):
                addprice=(20*days)
                total_price=base_fee+addprice
                discount=total_price*(1 - 0.10)
                print(f"rantal days is : {days} ")
                print(f"optional service charge is : {addprice}\ntotal price without discount is : {total_price}")
                print(f"but you are Standard user so discount is 10 % \n\n total price including discount :{discount}  ") 
            elif(Insurance=="no")and (GPS=="yes"):
                addprice=(5*days)
                total_price=base_fee+addprice
                discount=total_price*(1 - 0.10)
                print(f"rantal days is : {days} ")
                print(f"optional service charge is : {addprice}\ntotal price without discount is : {total_price}")
                print(f'''but you are "Standard" user so discount is 10 % \n\n total price including discount :{discount}  ''') 
            elif(Insurance=="no")and (GPS=="no"):
                addprice=0
                total_price=base_fee+addprice
                discount=total_price*(1 - 0.10)
                print(f"rantal days is : {days} ")
                print(f"optional service charge is : {addprice}\ntotal price without discount is : {total_price}")
                print(f'''but you are "Standard" user so discount is 10 % \n\n total price including discount :{discount}  ''')
            else:
                print("Please enter valid Optional service.........!")  
                
# car type is Economy and membership is none   
        else :
            if(Insurance=="yes")and (GPS=="yes"):
                addprice=(20*days)+(5*days)
                total_price=base_fee+addprice
                discount=total_price
                print(f"rantal days is : {days} ")
                print(f"optional service charge is : {addprice}\ntotal price without discount is : {total_price}")
                print(f'''but you are none membership user so no discount is available sorry.....!\n\n total price is :{discount}  ''')
            elif(Insurance=="yes")and (GPS=="no"):
                addprice=(20*days)
                total_price=base_fee+addprice
                discount=total_price
                print(f"rantal days is : {days} ")
                print(f"optional service charge is : {addprice}\ntotal price without discount is : {total_price}")
                print(f"but you are none membership user so no discount is available sorry.....!\n\n total price is :{discount} ")
            elif(Insurance=="no")and (GPS=="yes"):
                addprice=(5*days)
                total_price=base_fee+addprice
                discount=total_price
                print(f"rantal days is : {days} ")
                print(f"optional service charge is : {addprice}\ntotal price without discount is : {total_price}")
                print(f'''but you are none membership user so no discount is available sorry.....! \n\n total price is :{discount}''')  
            elif(Insurance=="no")and (GPS=="no"):
                addprice=0
                total_price=base_fee+addprice
                discount=total_price
                print(f"rantal days is : {days} ")
                print(f"optional service charge is : {addprice}\ntotal price without discount is : {total_price}")
                print(f'''but you are none membership user so no discount is available sorry.....! \n\n total price is :{discount}''') 
            else:
                print("Please enter valid Optional service.........!")  

# car type if standard   
    elif (cartype=="Standard"):
        print(f"rental rates for car type : Standard is ${Standard}/day ")
        base_fee=75*days
# car type if standard and membership type is Premium
        if (mtype=="Premium"): 
            if (Insurance=="yes")and (GPS=="yes"):
                addprice=(20*days)+(5*days)
                total_price=base_fee+addprice
                discount=total_price*(1 - 0.15)
                print(f"rantal days is : {days} ")
                print(f"optional service charge is : {addprice}\ntotal price without discount is : {total_price}")
                print(f"but you are premium user so discount is 15 % \n\n total price including discount :{discount}  ")
            elif(Insurance=="yes")and (GPS=="no"):
                addprice=(20*days)
                total_price=base_fee+addprice
                discount=total_price*(1 - 0.15)
                print(f"rantal days is : {days} ")
                print(f"optional service charge is : {addprice}\ntotal price without discount is : {total_price}")
                print(f"but you are premium user so discount is 15 % \n\n total price including discount :{discount}  ")  
            elif(Insurance=="no")and (GPS=="yes"):
                addprice=(5*days)
                total_price=base_fee+addprice
                discount=total_price*(1 - 0.15)
                print(f"rantal days is : {days} ")
                print(f"optional service charge is : {addprice}\ntotal price without discount is : {total_price}")
                print(f"but you are premium user so discount is 15 % \n\n total price including discount :{discount}  ")  
            elif(Insurance=="no")and (GPS=="no"):
                addprice=0
                total_price=base_fee+addprice
                discount=total_price*(1 - 0.15)
                print(f"rantal days is : {days} ")
                print(f"optional service charge is : {addprice}\ntotal price without discount is : {total_price}")
                print(f"but you are premium user so discount is 15 % \n\n total price including discount :{discount}  ")
            else:
                print("Please enter valid Optional service.........!")  

# if car type is standard and membership type is Standard            
        elif (mtype=="Standard"):
            if (Insurance=="yes")and (GPS=="yes"):
                addprice=(20*days)+(5*days)
                total_price=base_fee+addprice
                discount=total_price*(1 - 0.10)
                print(f"rantal days is : {days} ")
                print(f"optional service charge is : {addprice}\ntotal price without discount is : {total_price}")
                print(f'''but you are "Standard" user so discount is 10 % \n\n total price including discount :{discount}  ''')
            elif(Insurance=="yes")and (GPS=="no"):
                addprice=(20*days)
                total_price=base_fee+addprice
                discount=total_price*(1 - 0.10)
                print(f"rantal days is : {days} ")
                print(f"optional service charge is : {addprice}\ntotal price without discount is : {total_price}")
                print(f"but you are Standard user so discount is 10 % \n\n total price including discount :{discount}  ") 
            elif(Insurance=="no")and (GPS=="yes"):
                addprice=(5*days)
                total_price=base_fee+addprice
                discount=total_price*(1 - 0.10)
                print(f"rantal days is : {days} ")
                print(f"optional service charge is : {addprice}\ntotal price without discount is : {total_price}")
                print(f'''but you are "Standard" user so discount is 10 % \n\n total price including discount :{discount}  ''')
            elif(Insurance=="no")and (GPS=="no"):
                addprice=0
                total_price=base_fee+addprice
                discount=total_price*(1 - 0.10)
                print(f"rantal days is : {days} ")
                print(f"optional service charge is : {addprice}\ntotal price without discount is : {total_price}")
                print(f'''but you are "Standard" user so discount is 10 % \n\n total price including discount :{discount}  ''')
            else:
                print("Please enter valid Optional service.........!")  

# if car type is standard and membership type is none           
        else :
            if(Insurance=="yes")and (GPS=="yes"):
                addprice=(20*days)+(5*days)
                total_price=base_fee+addprice
                discount=total_price
                print(f"rantal days is : {days} ")
                print(f"optional service charge is : {addprice}\ntotal price without discount is : {total_price}")
                print(f'''but you are none membership user so no discount is available sorry.....!\n\n total price is :{discount}  ''')
            elif(Insurance=="yes")and (GPS=="no"):
                addprice=(20*days)
                total_price=base_fee+addprice
                discount=total_price
                print(f"rantal days is : {days} ")
                print(f"optional service charge is : {addprice}\ntotal price without discount is : {total_price}")
                print(f"but you are none membership user so no discount is available sorry.....!\n\n total price is :{discount} ")
            elif(Insurance=="no")and (GPS=="yes"):
                addprice=(5*days)
                total_price=base_fee+addprice
                discount=total_price
                print(f"rantal days is : {days} ")
                print(f"optional service charge is : {addprice}\ntotal price without discount is : {total_price}")
                print(f'''but you are none membership user so no discount is available sorry.....! \n\n total price is :{discount}''')
            elif(Insurance=="no")and (GPS=="no"):
                addprice=0
                total_price=base_fee+addprice
                discount=total_price
                print(f"rantal days is : {days} ")
                print(f"optional service charge is : {addprice}\ntotal price without discount is : {total_price}")
                print(f'''but you are none membership user so no discount is available sorry.....! \n\n total price is :{discount}''')
            else:
                print("Please enter valid Optional service.........!")  

# if car type is Luxury
    elif (cartype=="Luxury"):
        print(f"rental rates for car type : Luxury is ${Luxury}/day ")
        base_fee=100*days
# if car type is Luxuryand  membership type is Premium
        if (mtype=="Premium"):
            if (Insurance=="yes")and (GPS=="yes"):
                addprice=(20*days)+(5*days)
                total_price=base_fee+addprice
                discount=total_price*(1 - 0.15)
                print(f"rantal days is : {days} ")
                print(f"optional service charge is : {addprice}\ntotal price without discount is : {total_price}")
                print(f"but you are premium user so discount is 15 % \n\n total price including discount :{discount}  ")
            elif(Insurance=="yes")and (GPS=="no"):
                addprice=(20*days)
                total_price=base_fee+addprice
                discount=total_price*(1 - 0.15)
                print(f"rantal days is : {days} ")
                print(f"optional service charge is : {addprice}\ntotal price without discount is : {total_price}")
                print(f"but you are premium user so discount is 15 % \n\n total price including discount :{discount}  ")
            elif(Insurance=="no")and (GPS=="yes"):
                addprice=(5*days)
                total_price=base_fee+addprice
                discount=total_price*(1 - 0.15)
                print(f"rantal days is : {days} ")
                print(f"optional service charge is : {addprice}\ntotal price without discount is : {total_price}")
                print(f"but you are premium user so discount is 15 % \n\n total price including discount :{discount}  ") 
            elif(Insurance=="no")and (GPS=="no"):
                addprice=0
                total_price=base_fee+addprice
                discount=total_price*(1 - 0.15)
                print(f"rantal days is : {days} ")
                print(f"optional service charge is : {addprice}\ntotal price without discount is : {total_price}")
                print(f"but you are premium user so discount is 15 % \n\n total price including discount :{discount}  ") 
            else:
                print("Please enter valid Optional service.........!")  
          
# car type Luxury and membership is standard    
        elif (mtype=="Standard"):
            if (Insurance=="yes")and (GPS=="yes"):
                addprice=(20*days)+(5*days)
                total_price=base_fee+addprice
                discount=total_price*(1 - 0.10)
                print(f"rantal days is : {days} ")
                print(f"optional service charge is : {addprice}\ntotal price without discount is : {total_price}")
                print(f'''but you are "Standard" user so discount is 10 % \n\n total price including discount :{discount}  ''')
            elif(Insurance=="yes")and (GPS=="no"):
                addprice=(20*days)
                total_price=base_fee+addprice
                discount=total_price*(1 - 0.10)
                print(f"rantal days is : {days} ")
                print(f"optional service charge is : {addprice}\ntotal price without discount is : {total_price}")
                print(f"but you are Standard user so discount is 10 % \n\n total price including discount :{discount}  ") 
            elif(Insurance=="no")and (GPS=="yes"):
                addprice=(5*days)
                total_price=base_fee+addprice
                discount=total_price*(1 - 0.10)
                print(f"rantal days is : {days} ")
                print(f"optional service charge is : {addprice}\ntotal price without discount is : {total_price}")
                print(f'''but you are "Standard" user so discount is 10 % \n\n total price including discount :{discount}  ''')
            elif(Insurance=="no")and (GPS=="no"):
                addprice=0
                total_price=base_fee+addprice
                discount=total_price*(1 - 0.10)
                print(f"rantal days is : {days} ")
                print(f"optional service charge is : {addprice}\ntotal price without discount is : {total_price}")
                print(f'''but you are "Standard" user so discount is 10 % \n\n total price including discount :{discount}  ''')
            else:
                print("Please enter valid Optional service.........!")  

# car type Luxury and membership is none
        else :
            if(Insurance=="yes")and (GPS=="yes"):
                addprice=(20*days)+(5*days)
                total_price=base_fee+addprice
                discount=total_price
                print(f"rantal days is : {days} ")
                print(f"optional service charge is : {addprice}\ntotal price without discount is : {total_price}")
                print(f'''but you are none membership user so no discount is available sorry.....!\n\n total price is :{discount}  ''')
            elif(Insurance=="yes")and (GPS=="no"):
                addprice=(20*days)
                total_price=base_fee+addprice
                discount=total_price
                print(f"rantal days is : {days} ")
                print(f"optional service charge is : {addprice}\ntotal price without discount is : {total_price}")
                print(f"but you are none membership user so no discount is available sorry.....!\n\n total price is :{discount} ")
            elif(Insurance=="no")and (GPS=="yes"):
                addprice=(5*days)
                total_price=base_fee+addprice
                discount=total_price
                print(f"rantal days is : {days} ")
                print(f"optional service charge is : {addprice}\ntotal price without discount is : {total_price}")
                print(f'''but you are none membership user so no discount is available sorry.....! \n\n total price is :{discount}''')  
            elif(Insurance=="no")and (GPS=="no"):
                addprice=0
                total_price=base_fee+addprice
                discount=total_price
                print(f"rantal days is : {days} ")
                print(f"optional service charge is : {addprice}\ntotal price without discount is : {total_price}")
                print(f'''but you are none membership user so no discount is available sorry.....! \n\n total price is :{discount}''') 
            else:
                print("Please enter valid Optional service.........!") 
    else:
        print(f"please enter valid car type, you have entered : {cartype}")

# if car type is wrong          
else :
    print(f" please enter valid days you have entered : {days} \n            EXIT ")
print("\n\n****************VISIT-AGAIN**********************")
# Out:
# ******************WEL-COME**********************
# Enter car type form it (Economy, Standard, or Luxury) :  Standard
# Enter the number of rental days:  65
# Enter your membership type (Premium, Standard, or none)  Premium
# optional services (Insurance and GPS)
# Insurance fee at $20 per day (yes or no):  yes
# GPS fee at $5 per day (yes or no):  no
# ******************THANK-YOU**********************
#
#
# rental rates for car type : Standard is $75/day
# rantal days is : 65
# optional service charge is : 1300
# total price without discount is : 6175
# but you are premium user so discount is 15 %
#
#  total price including discount :5248.75
#
#
# ****************VISIT-AGAIN**********************

# %% [markdown]
# ### Task 5: Calculate Late Return Penalty

# %% [raw]
# Objective: Add a penalty fee for any late returns.
# Steps:
# 1. Prompt the user to enter the number of days the car was returned late.
# 2. If the car was returned late (greater than 0 days), calculate a penalty of $30 per late day.
# 3. Use conditional statements to apply this penalty only if late days are entered.
# Expected Output: The total late return penalty

# %%
#### print("******************WEL-COME**********************\n\n")
cartype=input("Enter car type form it (Economy, Standard, or Luxury) : ")
Economy= 50
Standard=75
Luxury= 100
days=input("Enter the number of rental days: ")
mtype=input("Enter your membership type (Premium, Standard, or none) ")
print("optional services (Insurance and GPS)")
Insurance=input("Insurance fee at $20 per day (yes or no): ")
GPS=input("GPS fee at $5 per day (yes or no): ")
latepenalty=int(input("enter the number of days the car was returned late : "))
print("\n\n******************THANK-YOU**********************")
print("\n")

days=int(days)
if (days>0) :

# if car type is Economy  
    if (cartype=="Economy"):
        print(f"rental rates for car type : Economy is ${Economy}/day  ")
        base_fee=50*days
# car type is Economy and membership is Premium   
        if (mtype=="Premium"): 
            if (Insurance=="yes")and (GPS=="yes") :
                if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=50*days
                    latepenalty=latepenalty*30
                    addprice=(20*days)+(5*days)+latepenalty
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.15)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is (including penalty({latepenalty}): {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are premium user so discount is 15 % \n\n total price including discount :{discount}  ")
                else:
                    addprice=(20*days)+(5*days)
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.15)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are premium user so discount is 15 % \n\n total price including discount :{discount}  ")
                    
            elif(Insurance=="yes")and (GPS=="no"):
                if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=50*days
                    latepenalty=latepenalty*30
                    addprice=(20*days)+latepenalty
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.15)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is (including penalty({latepenalty}) : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are premium user so discount is 15 % \n\n total price including discount :{discount}  ")
                else:
                    addprice=(20*days)
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.15)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are premium user so discount is 15 % \n\n total price including discount :{discount}  ")
                    
            elif(Insurance=="no")and (GPS=="yes"):
                if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=50*days
                    latepenalty=latepenalty*30
                    addprice=(5*days)+latepenalty
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.15)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are premium user so discount is 15 % \n\n total price including discount :{discount}  ")
                else:
                    addprice=(5*days)
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.15)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice}\ntotal price without discount is : {total_price}")
                    print(f"but you are premium user so discount is 15 % \n\n total price including discount :{discount}  ") 

            elif(Insurance=="no")and (GPS=="no"):
                if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=50*days
                    latepenalty=latepenalty*30
                    total_price=base_fee+latepenalty
                    discount=total_price*(1 - 0.15)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {latepenalty} \ntotal price without discount is : {total_price}")
                    print(f"but you are premium user so discount is 15 % \n\n total price including discount :{discount}  ")
                else:
                    total_price=base_fee
                    discount=total_price*(1 - 0.15)
                    print(f"rantal days is : {days} ")
                    print(f"\ntotal price without discount is : {total_price}")
                    print(f"but you are premium user so discount is 15 % \n\n total price including discount :{discount}  ")  
            else:
                print("Please enter valid Optional service.........!")  

# car type is Economy and membership is standard
        elif (mtype=="Standard"):         
            if (Insurance=="yes")and (GPS=="yes"):
                 if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=50*days
                    latepenalty=latepenalty*30
                    addprice=(20*days)+(5*days)+latepenalty
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.10)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is (including penalty({latepenalty}): {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are standard user so discount is 10 % \n\n total price including discount :{discount}  ")
                 else:
                    addprice=(20*days)+(5*days)
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.10)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are standard user so discount is 10 % \n\n total price including discount :{discount}  ")
                    
            elif(Insurance=="yes")and (GPS=="no"):
                if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=50*days
                    latepenalty=latepenalty*30
                    addprice=(20*days)+latepenalty
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.10)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is (including penalty({latepenalty}) : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are Standard user so discount is 10 % \n\n total price including discount :{discount}  ")
                else:
                    addprice=(20*days)
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.10)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are Standard user so discount is 10 % \n\n total price including discount :{discount}  ")
                    
            elif(Insurance=="no")and (GPS=="yes"):
                if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=50*days
                    latepenalty=latepenalty*30
                    addprice=(5*days)+latepenalty
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.10)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are standard user so discount is 10 % \n\n total price including discount :{discount}  ")
                else:
                    addprice=(5*days)
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.10)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice}\ntotal price without discount is : {total_price}")
                    print(f"but you are standard user so discount is 10 % \n\n total price including discount :{discount}  ") 

                
            elif(Insurance=="no")and (GPS=="no"):
                if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=50*days
                    latepenalty=latepenalty*30
                    total_price=base_fee+latepenalty
                    discount=total_price*(1 - 0.10)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {latepenalty} \ntotal price without discount is : {total_price}")
                    print(f"but you are standard user so discount is 10 % \n\n total price including discount :{discount}  ")
                else:
                    total_price=base_fee
                    discount=total_price*(1 - 0.10)
                    print(f"rantal days is : {days} ")
                    print(f"\ntotal price without discount is : {total_price}")
                    print(f"but you are standard user so discount is 10 % \n\n total price including discount :{discount}  ")
                    
            else:
                print("Please enter valid Optional service.........!")  
                
# car type is Economy and membership is none   
        else :
            if(Insurance=="yes")and (GPS=="yes"):
                if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=50*days
                    latepenalty=latepenalty*30
                    addprice=(20*days)+(5*days)+latepenalty
                    total_price=base_fee+addprice
                    discount=total_price
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is (including penalty({latepenalty}): {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are none membership user so no discount for you \n\n total price including discount :{discount}  ")
                else:
                    addprice=(20*days)+(5*days)
                    total_price=base_fee+addprice
                    discount=total_price
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are none membership user so no discount for you \n\n total price including discount :{discount}  ")
                    
            elif(Insurance=="yes")and (GPS=="no"):
                if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=50*days
                    latepenalty=latepenalty*30
                    addprice=(20*days)+latepenalty
                    total_price=base_fee+addprice
                    discount=total_price
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is (including penalty({latepenalty}) : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are none membership user so no discount for you \n\n total price including discount :{discount}  ")
                else:
                    addprice=(20*days)
                    total_price=base_fee+addprice
                    discount=total_price
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are none membership user so no discount for you \n\n total price including discount :{discount}  ")
                        
            elif(Insurance=="no")and (GPS=="yes"):
                if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=50*days
                    latepenalty=latepenalty*30
                    addprice=(5*days)+latepenalty
                    total_price=base_fee+addprice
                    discount=total_price
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are none membership user so no discount for you \n\n total price including discount :{discount}  ")
                else:
                    addprice=(5*days)
                    total_price=base_fee+addprice
                    discount=total_price
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice}\ntotal price without discount is : {total_price}")
                    print(f"but you are none membership user so no discount for you \n\n total price including discount :{discount}  ") 
                
            elif(Insurance=="no")and (GPS=="no"):
                if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=50*days
                    latepenalty=latepenalty*30
                    total_price=base_fee+latepenalty
                    discount=total_price
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {latepenalty} \ntotal price without discount is : {total_price}")
                    print(f"but you are none membership user so no discount \n\n total price :{discount}  ")
                else:
                    total_price=base_fee
                    discount=total_price
                    print(f"rantal days is : {days} ")
                    print(f"\ntotal price without discount is : {total_price}")
                    print(f"but you are none membership user so discount \n\n total price  :{discount}  ") 
            else:
                print("Please enter valid Optional service.........!")  

# car type if standard   
    elif (cartype=="Standard"):
        print(f"rental rates for car type : Standard is ${Standard}/day ")
        base_fee=75*days
# car type if standard and membership type is Premium
        if (mtype=="Premium"): 
            if (Insurance=="yes")and (GPS=="yes"):
                if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=75*days
                    latepenalty=latepenalty*30
                    addprice=(20*days)+(5*days)+latepenalty
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.15)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is (including penalty({latepenalty})): {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are premium user so discount is 15 % \n\n total price including discount :{discount}  ")
                else:
                    addprice=(20*days)+(5*days)
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.15)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are premium user so discount is 15 % \n\n total price including discount :{discount}  ")
                    
            elif(Insurance=="yes")and (GPS=="no"):
                if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=75*days
                    latepenalty=latepenalty*30
                    addprice=(20*days)+latepenalty
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.15)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is (including penalty({latepenalty}) : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are premium user so discount is 15 % \n\n total price including discount :{discount}  ")
                else:
                    addprice=(20*days)
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.15)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are premium user so discount is 15 % \n\n total price including discount :{discount}  ")
                      
            elif(Insurance=="no")and (GPS=="yes"):
                 if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=75*days
                    latepenalty=latepenalty*30
                    addprice=(5*days)+latepenalty
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.15)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are premium user so discount is 15 % \n\n total price including discount :{discount}  ")
                 else:
                    addprice=(5*days)
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.15)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice}\ntotal price without discount is : {total_price}")
                    print(f"but you are premium user so discount is 15 % \n\n total price including discount :{discount}  ") 
                
            elif(Insurance=="no")and (GPS=="no"):
                if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=75*days
                    latepenalty=latepenalty*30
                    total_price=base_fee+latepenalty
                    discount=total_price*(1 - 0.15)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {latepenalty} \ntotal price without discount is : {total_price}")
                    print(f"but you are premium user so discount is 15 % \n\n total price including discount :{discount}  ")
                else:
                    total_price=base_fee
                    discount=total_price*(1 - 0.15)
                    print(f"rantal days is : {days} ")
                    print(f"\ntotal price without discount is : {total_price}")
                    print(f"but you are premium user so discount is 15 % \n\n total price including discount :{discount}  ")  
            else:
                print("Please enter valid Optional service.........!")  

# if car type is standard and membership type is Standard            
        elif (mtype=="Standard"):
            if (Insurance=="yes")and (GPS=="yes"):
                if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=75*days
                    latepenalty=latepenalty*30
                    addprice=(20*days)+(5*days)+latepenalty
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.10)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is (including penalty({latepenalty}): {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are standard user so discount is 10 % \n\n total price including discount :{discount}  ")
                else:
                    addprice=(20*days)+(5*days)
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.10)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are standard user so discount is 10 % \n\n total price including discount :{discount}  ")
                    
            elif(Insurance=="yes")and (GPS=="no"):
                if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=75*days
                    latepenalty=latepenalty*30
                    addprice=(20*days)+latepenalty
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.10)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is (including penalty({latepenalty}) : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are Standard user so discount is 10 % \n\n total price including discount :{discount}  ")
                else:
                    addprice=(20*days)
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.10)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are Standard user so discount is 10 % \n\n total price including discount :{discount}")
                
            elif(Insurance=="no")and (GPS=="yes"):
                if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=75*days
                    latepenalty=latepenalty*30
                    addprice=(5*days)+latepenalty
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.10)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are standard user so discount is 10 % \n\n total price including discount :{discount}  ")
                else:
                    addprice=(5*days)
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.10)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice}\ntotal price without discount is : {total_price}")
                    print(f"but you are standard user so discount is 10 % \n\n total price including discount :{discount}  ") 
            elif(Insurance=="no")and (GPS=="no"):
                if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=75*days
                    latepenalty=latepenalty*30
                    total_price=base_fee+latepenalty
                    discount=total_price*(1 - 0.10)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {latepenalty} \ntotal price without discount is : {total_price}")
                    print(f"but you are standard user so discount is 10 % \n\n total price including discount :{discount}  ")
                else:
                    total_price=base_fee
                    discount=total_price*(1 - 0.10)
                    print(f"rantal days is : {days} ")
                    print(f"\ntotal price without discount is : {total_price}")
                    print(f"but you are standard user so discount is 10 % \n\n total price including discount :{discount}  ")
                    
               
            else:
                print("Please enter valid Optional service.........!")  

# if car type is standard and membership type is none           
        else :
            if(Insurance=="yes")and (GPS=="yes"):
                if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=75*days
                    latepenalty=latepenalty*30
                    addprice=(20*days)+(5*days)+latepenalty
                    total_price=base_fee+addprice
                    discount=total_price
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is (including penalty({latepenalty}): {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are none membership user so no discount for you \n\n total price including discount :{discount}  ")
                else:
                    addprice=(20*days)+(5*days)
                    total_price=base_fee+addprice
                    discount=total_price
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are none membership user so no discount for you \n\n total price including discount :{discount}  ")
                    
            elif(Insurance=="yes")and (GPS=="no"):
                if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=75*days
                    latepenalty=latepenalty*30
                    addprice=(20*days)+latepenalty
                    total_price=base_fee+addprice
                    discount=total_price
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is (including penalty({latepenalty}) : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are none membership user so no discount for you \n\n total price including discount :{discount}  ")
                else:
                    addprice=(20*days)
                    total_price=base_fee+addprice
                    discount=total_price
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are none membership user so no discount for you \n\n total price including discount :{discount}  ")
            elif(Insurance=="no")and (GPS=="yes"):
                if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=75*days
                    latepenalty=latepenalty*30
                    addprice=(5*days)+latepenalty
                    total_price=base_fee+addprice
                    discount=total_price
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are none membership user so no discount for you \n\n total price including discount :{discount}  ")
                else:
                    addprice=(5*days)
                    total_price=base_fee+addprice
                    discount=total_price
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice}\ntotal price without discount is : {total_price}")
                    print(f"but you are none membership user so no discount for you \n\n total price including discount :{discount}  ") 
            elif(Insurance=="no")and (GPS=="no"):
                if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=75*days
                    latepenalty=latepenalty*30
                    total_price=base_fee+latepenalty
                    discount=total_price
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {latepenalty} \ntotal price without discount is : {total_price}")
                    print(f"but you are none membership user so no discount \n\n total price :{discount}  ")
                else:
                    total_price=base_fee
                    discount=total_price
                    print(f"rantal days is : {days} ")
                    print(f"\ntotal price without discount is : {total_price}")
                    print(f"but you are none membership user so discount \n\n total price  :{discount}  ") 
            else:
                print("Please enter valid Optional service.........!")  

# if car type is Luxury
    elif (cartype=="Luxury"):
        print(f"rental rates for car type : Luxury is ${Luxury}/day ")
        base_fee=100*days
# if car type is Luxury and  membership type is Premium
        if (mtype=="Premium"):
            if (Insurance=="yes")and (GPS=="yes"):
                if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=100*days
                    latepenalty=latepenalty*30
                    addprice=(20*days)+(5*days)+latepenalty
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.15)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is (including penalty({latepenalty})): {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are premium user so discount is 15 % \n\n total price including discount :{discount}  ")
                else:
                    addprice=(20*days)+(5*days)
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.15)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are premium user so discount is 15 % \n\n total price including discount :{discount}  ")
                
            elif(Insurance=="yes")and (GPS=="no"):
                if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=100*days
                    latepenalty=latepenalty*30
                    addprice=(20*days)+latepenalty
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.15)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is (including penalty({latepenalty}) : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are premium user so discount is 15 % \n\n total price including discount :{discount}  ")
                else:
                    addprice=(20*days)
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.15)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are premium user so discount is 15 % \n\n total price including discount :{discount}  ")
                    
            elif(Insurance=="no")and (GPS=="yes"):
                if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=100*days
                    latepenalty=latepenalty*30
                    addprice=(5*days)+latepenalty
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.15)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are premium user so discount is 15 % \n\n total price including discount :{discount}  ")
                else:
                    addprice=(5*days)
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.15)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice}\ntotal price without discount is : {total_price}")
                    print(f"but you are premium user so discount is 15 % \n\n total price including discount :{discount}  ") 
                
            elif(Insurance=="no")and (GPS=="no"):
                if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=100*days
                    latepenalty=latepenalty*30
                    total_price=base_fee+latepenalty
                    discount=total_price*(1 - 0.15)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {latepenalty} \ntotal price without discount is : {total_price}")
                    print(f"but you are premium user so discount is 15 % \n\n total price including discount :{discount}  ")
                else:
                    total_price=base_fee
                    discount=total_price*(1 - 0.15)
                    print(f"rantal days is : {days} ")
                    print(f"\ntotal price without discount is : {total_price}")
                    print(f"but you are premium user so discount is 15 % \n\n total price including discount :{discount}  ") 
            
            else:
                print("Please enter valid Optional service.........!")  
          
# car type Luxury and membership is standard    
        elif (mtype=="Standard"):
            if (Insurance=="yes")and (GPS=="yes"):
                if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=100*days
                    latepenalty=latepenalty*30
                    addprice=(20*days)+(5*days)+latepenalty
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.10)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is (including penalty({latepenalty}): {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are standard user so discount is 10 % \n\n total price including discount :{discount}  ")
                else:
                    addprice=(20*days)+(5*days)
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.10)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are standard user so discount is 10 % \n\n total price including discount :{discount}  ")
                
            elif(Insurance=="yes")and (GPS=="no"):
                if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=100*days
                    latepenalty=latepenalty*30
                    addprice=(20*days)+latepenalty
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.10)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is (including penalty({latepenalty}) : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are Standard user so discount is 10 % \n\n total price including discount :{discount}  ")
                else:
                    addprice=(20*days)
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.10)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are Standard user so discount is 10 % \n\n total price including discount :{discount}  ")
            elif(Insurance=="no")and (GPS=="yes"):
                if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=100*days
                    latepenalty=latepenalty*30
                    addprice=(5*days)+latepenalty
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.10)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are standard user so discount is 10 % \n\n total price including discount :{discount}  ")
                else:
                    addprice=(5*days)
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.10)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice}\ntotal price without discount is : {total_price}")
                    print(f"but you are standard user so discount is 10 % \n\n total price including discount :{discount}  ") 
                
            elif(Insurance=="no")and (GPS=="no"):
                if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=100*days
                    latepenalty=latepenalty*30
                    total_price=base_fee+latepenalty
                    discount=total_price*(1 - 0.10)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {latepenalty} \ntotal price without discount is : {total_price}")
                    print(f"but you are standard user so discount is 10 % \n\n total price including discount :{discount}  ")
                else:
                    total_price=base_fee
                    discount=total_price*(1 - 0.10)
                    print(f"rantal days is : {days} ")
                    print(f"\ntotal price without discount is : {total_price}")
                    print(f"but you are standard user so discount is 10 % \n\n total price including discount :{discount}  ") 
            else:
                print("Please enter valid Optional service.........!")  

# car type Luxury and membership is none
        else :
            if(Insurance=="yes")and (GPS=="yes"):
                if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=100*days
                    latepenalty=latepenalty*30
                    addprice=(20*days)+(5*days)+latepenalty
                    total_price=base_fee+addprice
                    discount=total_price
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is (including penalty({latepenalty}): {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are none membership user so no discount for you \n\n total price including discount :{discount}  ")
                else:
                    addprice=(20*days)+(5*days)
                    total_price=base_fee+addprice
                    discount=total_price
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are none membership user so no discount for you \n\n total price including discount :{discount}  ")

            elif(Insurance=="yes")and (GPS=="no"):
                if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=100*days
                    latepenalty=latepenalty*30
                    addprice=(20*days)+latepenalty
                    total_price=base_fee+addprice
                    discount=total_price
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is (including penalty({latepenalty}) : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are none membership user so no discount for you \n\n total price including discount :{discount}  ")
                else:
                    addprice=(20*days)
                    total_price=base_fee+addprice
                    discount=total_price
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are none membership user so no discount for you \n\n total price including discount :{discount}  ")
            elif(Insurance=="no")and (GPS=="yes"):
                if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=100*days
                    latepenalty=latepenalty*30
                    addprice=(5*days)+latepenalty
                    total_price=base_fee+addprice
                    discount=total_price
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are none membership user so no discount for you \n\n total price including discount :{discount}  ")
                else:
                    addprice=(5*days)
                    total_price=base_fee+addprice
                    discount=total_price
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice}\ntotal price without discount is : {total_price}")
                    print(f"but you are none membership user so no discount for you \n\n total price including discount :{discount}  ") 
                
            elif(Insurance=="no")and (GPS=="no"):
                if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=100*days
                    latepenalty=latepenalty*30
                    total_price=base_fee+latepenalty
                    discount=total_price
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {latepenalty} \ntotal price without discount is : {total_price}")
                    print(f"but you are none membership user so no discount \n\n total price :{discount}  ")
                else:
                    total_price=base_fee
                    discount=total_price
                    print(f"rantal days is : {days} ")
                    print(f"\ntotal price without discount is : {total_price}")
                    print(f"but you are none membership user so discount \n\n total price  :{discount}  ") 
                
            else:
                print("Please enter valid Optional service.........!") 
    else:
        print(f"please enter valid car type, you have entered : {cartype}")

# if car type is wrong          
else :
    print(f" please enter valid days you have entered : {days} \n            EXIT ")
print("\n\n****************VISIT-AGAIN**********************")
# Out:
# Enter car type form it (Economy, Standard, or Luxury) :  Luxury
# Enter the number of rental days:  4
# Enter your membership type (Premium, Standard, or none)  Premium
# optional services (Insurance and GPS)
# Insurance fee at $20 per day (yes or no):  yes
# GPS fee at $5 per day (yes or no):  yes
# enter the number of days the car was returned late :  2
# ******************THANK-YOU**********************
#
#
# rental rates for car type : Luxury is $100/day
# rantal days is : 6
# optional service charge is (including penalty(60)): 210
# total price without discount is : 810
# but you are premium user so discount is 15 %
#
#  total price including discount :688.5
#
#
# ****************VISIT-AGAIN**********************

# %% [markdown]
# ### Task 6: Calculate and Display Total Rental Fee

# %% [raw]
# Objective: Summarize all fees and display the total rental cost.
# 1.Sum up the base_fee, membership discount, additional services, and late penalty.
# 2.Display a detailed breakdown of the costs, including:
#    - Car type and daily rate
#    - Number of rental days
#    - Membership discount
#    - Additional services fee
#    - Late return penalty
#    - Total rental fee
# 3. Format the output for clear and readable presentation to the user.
# Expected Output: A summary of all charges with a clear breakdown of the total rental fee.

# %%
#### print("******************WEL-COME**********************\n\n")
cartype=input("Enter car type form it (Economy, Standard, or Luxury) : ")
Economy= 50
Standard=75
Luxury= 100
days=input("Enter the number of rental days: ")
mtype=input("Enter your membership type (Premium, Standard, or none) ")
print("optional services (Insurance and GPS)")
Insurance=input("Insurance fee at $20 per day (yes or no): ")
GPS=input("GPS fee at $5 per day (yes or no): ")
latepenalty=int(input("enter the number of days the car was returned late : "))
print("\n\n******************THANK-YOU**********************")
print("\n")

days=int(days)
if (days>0) :

# if car type is Economy  
    if (cartype=="Economy"):
        print(f"rental rates for car type : Economy is ${Economy}/day  ")
        base_fee=50*days
# car type is Economy and membership is Premium   
        if (mtype=="Premium"): 
            if (Insurance=="yes")and (GPS=="yes") :
                if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=50*days
                    latepenalty=latepenalty*30
                    addprice=(20*days)+(5*days)+latepenalty
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.15)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is (including penalty({latepenalty}): {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are premium user so discount is 15 % \n\n total price including discount :{discount}  ")
                else:
                    addprice=(20*days)+(5*days)
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.15)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are premium user so discount is 15 % \n\n total price including discount :{discount}  ")
                    
            elif(Insurance=="yes")and (GPS=="no"):
                if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=50*days
                    latepenalty=latepenalty*30
                    addprice=(20*days)+latepenalty
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.15)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is (including penalty({latepenalty}) : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are premium user so discount is 15 % \n\n total price including discount :{discount}  ")
                else:
                    addprice=(20*days)
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.15)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are premium user so discount is 15 % \n\n total price including discount :{discount}  ")
                    
            elif(Insurance=="no")and (GPS=="yes"):
                if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=50*days
                    latepenalty=latepenalty*30
                    addprice=(5*days)+latepenalty
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.15)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are premium user so discount is 15 % \n\n total price including discount :{discount}  ")
                else:
                    addprice=(5*days)
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.15)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice}\ntotal price without discount is : {total_price}")
                    print(f"but you are premium user so discount is 15 % \n\n total price including discount :{discount}  ") 

            elif(Insurance=="no")and (GPS=="no"):
                if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=50*days
                    latepenalty=latepenalty*30
                    total_price=base_fee+latepenalty
                    discount=total_price*(1 - 0.15)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {latepenalty} \ntotal price without discount is : {total_price}")
                    print(f"but you are premium user so discount is 15 % \n\n total price including discount :{discount}  ")
                else:
                    total_price=base_fee
                    discount=total_price*(1 - 0.15)
                    print(f"rantal days is : {days} ")
                    print(f"\ntotal price without discount is : {total_price}")
                    print(f"but you are premium user so discount is 15 % \n\n total price including discount :{discount}  ")  
            else:
                print("Please enter valid Optional service.........!")  

# car type is Economy and membership is standard
        elif (mtype=="Standard"):         
            if (Insurance=="yes")and (GPS=="yes"):
                 if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=50*days
                    latepenalty=latepenalty*30
                    addprice=(20*days)+(5*days)+latepenalty
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.10)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is (including penalty({latepenalty}): {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are standard user so discount is 10 % \n\n total price including discount :{discount}  ")
                 else:
                    addprice=(20*days)+(5*days)
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.10)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are standard user so discount is 10 % \n\n total price including discount :{discount}  ")
                    
            elif(Insurance=="yes")and (GPS=="no"):
                if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=50*days
                    latepenalty=latepenalty*30
                    addprice=(20*days)+latepenalty
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.10)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is (including penalty({latepenalty}) : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are Standard user so discount is 10 % \n\n total price including discount :{discount}  ")
                else:
                    addprice=(20*days)
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.10)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are Standard user so discount is 10 % \n\n total price including discount :{discount}  ")
                    
            elif(Insurance=="no")and (GPS=="yes"):
                if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=50*days
                    latepenalty=latepenalty*30
                    addprice=(5*days)+latepenalty
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.10)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are standard user so discount is 10 % \n\n total price including discount :{discount}  ")
                else:
                    addprice=(5*days)
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.10)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice}\ntotal price without discount is : {total_price}")
                    print(f"but you are standard user so discount is 10 % \n\n total price including discount :{discount}  ") 

                
            elif(Insurance=="no")and (GPS=="no"):
                if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=50*days
                    latepenalty=latepenalty*30
                    total_price=base_fee+latepenalty
                    discount=total_price*(1 - 0.10)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {latepenalty} \ntotal price without discount is : {total_price}")
                    print(f"but you are standard user so discount is 10 % \n\n total price including discount :{discount}  ")
                else:
                    total_price=base_fee
                    discount=total_price*(1 - 0.10)
                    print(f"rantal days is : {days} ")
                    print(f"\ntotal price without discount is : {total_price}")
                    print(f"but you are standard user so discount is 10 % \n\n total price including discount :{discount}  ")
                    
            else:
                print("Please enter valid Optional service.........!")  
                
# car type is Economy and membership is none   
        else :
            if(Insurance=="yes")and (GPS=="yes"):
                if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=50*days
                    latepenalty=latepenalty*30
                    addprice=(20*days)+(5*days)+latepenalty
                    total_price=base_fee+addprice
                    discount=total_price
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is (including penalty({latepenalty}): {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are none membership user so no discount for you \n\n total price including discount :{discount}  ")
                else:
                    addprice=(20*days)+(5*days)
                    total_price=base_fee+addprice
                    discount=total_price
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are none membership user so no discount for you \n\n total price including discount :{discount}  ")
                    
            elif(Insurance=="yes")and (GPS=="no"):
                if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=50*days
                    latepenalty=latepenalty*30
                    addprice=(20*days)+latepenalty
                    total_price=base_fee+addprice
                    discount=total_price
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is (including penalty({latepenalty}) : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are none membership user so no discount for you \n\n total price including discount :{discount}  ")
                else:
                    addprice=(20*days)
                    total_price=base_fee+addprice
                    discount=total_price
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are none membership user so no discount for you \n\n total price including discount :{discount}  ")
                        
            elif(Insurance=="no")and (GPS=="yes"):
                if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=50*days
                    latepenalty=latepenalty*30
                    addprice=(5*days)+latepenalty
                    total_price=base_fee+addprice
                    discount=total_price
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are none membership user so no discount for you \n\n total price including discount :{discount}  ")
                else:
                    addprice=(5*days)
                    total_price=base_fee+addprice
                    discount=total_price
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice}\ntotal price without discount is : {total_price}")
                    print(f"but you are none membership user so no discount for you \n\n total price including discount :{discount}  ") 
                
            elif(Insurance=="no")and (GPS=="no"):
                if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=50*days
                    latepenalty=latepenalty*30
                    total_price=base_fee+latepenalty
                    discount=total_price
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {latepenalty} \ntotal price without discount is : {total_price}")
                    print(f"but you are none membership user so no discount \n\n total price :{discount}  ")
                else:
                    total_price=base_fee
                    discount=total_price
                    print(f"rantal days is : {days} ")
                    print(f"\ntotal price without discount is : {total_price}")
                    print(f"but you are none membership user so discount \n\n total price  :{discount}  ") 
            else:
                print("Please enter valid Optional service.........!")  

# car type if standard   
    elif (cartype=="Standard"):
        print(f"rental rates for car type : Standard is ${Standard}/day ")
        base_fee=75*days
# car type if standard and membership type is Premium
        if (mtype=="Premium"): 
            if (Insurance=="yes")and (GPS=="yes"):
                if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=75*days
                    latepenalty=latepenalty*30
                    addprice=(20*days)+(5*days)+latepenalty
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.15)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is (including penalty({latepenalty})): {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are premium user so discount is 15 % \n\n total price including discount :{discount}  ")
                else:
                    addprice=(20*days)+(5*days)
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.15)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are premium user so discount is 15 % \n\n total price including discount :{discount}  ")
                    
            elif(Insurance=="yes")and (GPS=="no"):
                if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=75*days
                    latepenalty=latepenalty*30
                    addprice=(20*days)+latepenalty
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.15)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is (including penalty({latepenalty}) : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are premium user so discount is 15 % \n\n total price including discount :{discount}  ")
                else:
                    addprice=(20*days)
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.15)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are premium user so discount is 15 % \n\n total price including discount :{discount}  ")
                      
            elif(Insurance=="no")and (GPS=="yes"):
                 if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=75*days
                    latepenalty=latepenalty*30
                    addprice=(5*days)+latepenalty
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.15)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are premium user so discount is 15 % \n\n total price including discount :{discount}  ")
                 else:
                    addprice=(5*days)
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.15)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice}\ntotal price without discount is : {total_price}")
                    print(f"but you are premium user so discount is 15 % \n\n total price including discount :{discount}  ") 
                
            elif(Insurance=="no")and (GPS=="no"):
                if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=75*days
                    latepenalty=latepenalty*30
                    total_price=base_fee+latepenalty
                    discount=total_price*(1 - 0.15)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {latepenalty} \ntotal price without discount is : {total_price}")
                    print(f"but you are premium user so discount is 15 % \n\n total price including discount :{discount}  ")
                else:
                    total_price=base_fee
                    discount=total_price*(1 - 0.15)
                    print(f"rantal days is : {days} ")
                    print(f"\ntotal price without discount is : {total_price}")
                    print(f"but you are premium user so discount is 15 % \n\n total price including discount :{discount}  ")  
            else:
                print("Please enter valid Optional service.........!")  

# if car type is standard and membership type is Standard            
        elif (mtype=="Standard"):
            if (Insurance=="yes")and (GPS=="yes"):
                if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=75*days
                    latepenalty=latepenalty*30
                    addprice=(20*days)+(5*days)+latepenalty
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.10)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is (including penalty({latepenalty}): {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are standard user so discount is 10 % \n\n total price including discount :{discount}  ")
                else:
                    addprice=(20*days)+(5*days)
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.10)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are standard user so discount is 10 % \n\n total price including discount :{discount}  ")
                    
            elif(Insurance=="yes")and (GPS=="no"):
                if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=75*days
                    latepenalty=latepenalty*30
                    addprice=(20*days)+latepenalty
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.10)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is (including penalty({latepenalty}) : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are Standard user so discount is 10 % \n\n total price including discount :{discount}  ")
                else:
                    addprice=(20*days)
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.10)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are Standard user so discount is 10 % \n\n total price including discount :{discount}")
                
            elif(Insurance=="no")and (GPS=="yes"):
                if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=75*days
                    latepenalty=latepenalty*30
                    addprice=(5*days)+latepenalty
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.10)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are standard user so discount is 10 % \n\n total price including discount :{discount}  ")
                else:
                    addprice=(5*days)
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.10)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice}\ntotal price without discount is : {total_price}")
                    print(f"but you are standard user so discount is 10 % \n\n total price including discount :{discount}  ") 
            elif(Insurance=="no")and (GPS=="no"):
                if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=75*days
                    latepenalty=latepenalty*30
                    total_price=base_fee+latepenalty
                    discount=total_price*(1 - 0.10)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {latepenalty} \ntotal price without discount is : {total_price}")
                    print(f"but you are standard user so discount is 10 % \n\n total price including discount :{discount}  ")
                else:
                    total_price=base_fee
                    discount=total_price*(1 - 0.10)
                    print(f"rantal days is : {days} ")
                    print(f"\ntotal price without discount is : {total_price}")
                    print(f"but you are standard user so discount is 10 % \n\n total price including discount :{discount}  ")
                    
               
            else:
                print("Please enter valid Optional service.........!")  

# if car type is standard and membership type is none           
        else :
            if(Insurance=="yes")and (GPS=="yes"):
                if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=75*days
                    latepenalty=latepenalty*30
                    addprice=(20*days)+(5*days)+latepenalty
                    total_price=base_fee+addprice
                    discount=total_price
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is (including penalty({latepenalty}): {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are none membership user so no discount for you \n\n total price including discount :{discount}  ")
                else:
                    addprice=(20*days)+(5*days)
                    total_price=base_fee+addprice
                    discount=total_price
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are none membership user so no discount for you \n\n total price including discount :{discount}  ")
                    
            elif(Insurance=="yes")and (GPS=="no"):
                if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=75*days
                    latepenalty=latepenalty*30
                    addprice=(20*days)+latepenalty
                    total_price=base_fee+addprice
                    discount=total_price
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is (including penalty({latepenalty}) : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are none membership user so no discount for you \n\n total price including discount :{discount}  ")
                else:
                    addprice=(20*days)
                    total_price=base_fee+addprice
                    discount=total_price
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are none membership user so no discount for you \n\n total price including discount :{discount}  ")
            elif(Insurance=="no")and (GPS=="yes"):
                if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=75*days
                    latepenalty=latepenalty*30
                    addprice=(5*days)+latepenalty
                    total_price=base_fee+addprice
                    discount=total_price
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are none membership user so no discount for you \n\n total price including discount :{discount}  ")
                else:
                    addprice=(5*days)
                    total_price=base_fee+addprice
                    discount=total_price
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice}\ntotal price without discount is : {total_price}")
                    print(f"but you are none membership user so no discount for you \n\n total price including discount :{discount}  ") 
            elif(Insurance=="no")and (GPS=="no"):
                if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=75*days
                    latepenalty=latepenalty*30
                    total_price=base_fee+latepenalty
                    discount=total_price
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {latepenalty} \ntotal price without discount is : {total_price}")
                    print(f"but you are none membership user so no discount \n\n total price :{discount}  ")
                else:
                    total_price=base_fee
                    discount=total_price
                    print(f"rantal days is : {days} ")
                    print(f"\ntotal price without discount is : {total_price}")
                    print(f"but you are none membership user so discount \n\n total price  :{discount}  ") 
            else:
                print("Please enter valid Optional service.........!")  

# if car type is Luxury
    elif (cartype=="Luxury"):
        print(f"rental rates for car type : Luxury is ${Luxury}/day ")
        base_fee=100*days
# if car type is Luxury and  membership type is Premium
        if (mtype=="Premium"):
            if (Insurance=="yes")and (GPS=="yes"):
                if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=100*days
                    latepenalty=latepenalty*30
                    addprice=(20*days)+(5*days)+latepenalty
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.15)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is (including penalty({latepenalty})): {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are premium user so discount is 15 % \n\n total price including discount :{discount}  ")
                else:
                    addprice=(20*days)+(5*days)
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.15)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are premium user so discount is 15 % \n\n total price including discount :{discount}  ")
                
            elif(Insurance=="yes")and (GPS=="no"):
                if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=100*days
                    latepenalty=latepenalty*30
                    addprice=(20*days)+latepenalty
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.15)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is (including penalty({latepenalty}) : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are premium user so discount is 15 % \n\n total price including discount :{discount}  ")
                else:
                    addprice=(20*days)
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.15)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are premium user so discount is 15 % \n\n total price including discount :{discount}  ")
                    
            elif(Insurance=="no")and (GPS=="yes"):
                if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=100*days
                    latepenalty=latepenalty*30
                    addprice=(5*days)+latepenalty
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.15)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are premium user so discount is 15 % \n\n total price including discount :{discount}  ")
                else:
                    addprice=(5*days)
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.15)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice}\ntotal price without discount is : {total_price}")
                    print(f"but you are premium user so discount is 15 % \n\n total price including discount :{discount}  ") 
                
            elif(Insurance=="no")and (GPS=="no"):
                if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=100*days
                    latepenalty=latepenalty*30
                    total_price=base_fee+latepenalty
                    discount=total_price*(1 - 0.15)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {latepenalty} \ntotal price without discount is : {total_price}")
                    print(f"but you are premium user so discount is 15 % \n\n total price including discount :{discount}  ")
                else:
                    total_price=base_fee
                    discount=total_price*(1 - 0.15)
                    print(f"rantal days is : {days} ")
                    print(f"\ntotal price without discount is : {total_price}")
                    print(f"but you are premium user so discount is 15 % \n\n total price including discount :{discount}  ") 
            
            else:
                print("Please enter valid Optional service.........!")  
          
# car type Luxury and membership is standard    
        elif (mtype=="Standard"):
            if (Insurance=="yes")and (GPS=="yes"):
                if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=100*days
                    latepenalty=latepenalty*30
                    addprice=(20*days)+(5*days)+latepenalty
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.10)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is (including penalty({latepenalty}): {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are standard user so discount is 10 % \n\n total price including discount :{discount}  ")
                else:
                    addprice=(20*days)+(5*days)
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.10)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are standard user so discount is 10 % \n\n total price including discount :{discount}  ")
                
            elif(Insurance=="yes")and (GPS=="no"):
                if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=100*days
                    latepenalty=latepenalty*30
                    addprice=(20*days)+latepenalty
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.10)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is (including penalty({latepenalty}) : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are Standard user so discount is 10 % \n\n total price including discount :{discount}  ")
                else:
                    addprice=(20*days)
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.10)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are Standard user so discount is 10 % \n\n total price including discount :{discount}  ")
            elif(Insurance=="no")and (GPS=="yes"):
                if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=100*days
                    latepenalty=latepenalty*30
                    addprice=(5*days)+latepenalty
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.10)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are standard user so discount is 10 % \n\n total price including discount :{discount}  ")
                else:
                    addprice=(5*days)
                    total_price=base_fee+addprice
                    discount=total_price*(1 - 0.10)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice}\ntotal price without discount is : {total_price}")
                    print(f"but you are standard user so discount is 10 % \n\n total price including discount :{discount}  ") 
                
            elif(Insurance=="no")and (GPS=="no"):
                if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=100*days
                    latepenalty=latepenalty*30
                    total_price=base_fee+latepenalty
                    discount=total_price*(1 - 0.10)
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {latepenalty} \ntotal price without discount is : {total_price}")
                    print(f"but you are standard user so discount is 10 % \n\n total price including discount :{discount}  ")
                else:
                    total_price=base_fee
                    discount=total_price*(1 - 0.10)
                    print(f"rantal days is : {days} ")
                    print(f"\ntotal price without discount is : {total_price}")
                    print(f"but you are standard user so discount is 10 % \n\n total price including discount :{discount}  ") 
            else:
                print("Please enter valid Optional service.........!")  

# car type Luxury and membership is none
        else :
            if(Insurance=="yes")and (GPS=="yes"):
                if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=100*days
                    latepenalty=latepenalty*30
                    addprice=(20*days)+(5*days)+latepenalty
                    total_price=base_fee+addprice
                    discount=total_price
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is (including penalty({latepenalty}): {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are none membership user so no discount for you \n\n total price including discount :{discount}  ")
                else:
                    addprice=(20*days)+(5*days)
                    total_price=base_fee+addprice
                    discount=total_price
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are none membership user so no discount for you \n\n total price including discount :{discount}  ")

            elif(Insurance=="yes")and (GPS=="no"):
                if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=100*days
                    latepenalty=latepenalty*30
                    addprice=(20*days)+latepenalty
                    total_price=base_fee+addprice
                    discount=total_price
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is (including penalty({latepenalty}) : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are none membership user so no discount for you \n\n total price including discount :{discount}  ")
                else:
                    addprice=(20*days)
                    total_price=base_fee+addprice
                    discount=total_price
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are none membership user so no discount for you \n\n total price including discount :{discount}  ")
            elif(Insurance=="no")and (GPS=="yes"):
                if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=100*days
                    latepenalty=latepenalty*30
                    addprice=(5*days)+latepenalty
                    total_price=base_fee+addprice
                    discount=total_price
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice} \ntotal price without discount is : {total_price}")
                    print(f"but you are none membership user so no discount for you \n\n total price including discount :{discount}  ")
                else:
                    addprice=(5*days)
                    total_price=base_fee+addprice
                    discount=total_price
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {addprice}\ntotal price without discount is : {total_price}")
                    print(f"but you are none membership user so no discount for you \n\n total price including discount :{discount}  ") 
                
            elif(Insurance=="no")and (GPS=="no"):
                if(latepenalty>0):
                    days=days+latepenalty
                    base_fee=100*days
                    latepenalty=latepenalty*30
                    total_price=base_fee+latepenalty
                    discount=total_price
                    print(f"rantal days is : {days} ")
                    print(f"optional service charge is : {latepenalty} \ntotal price without discount is : {total_price}")
                    print(f"but you are none membership user so no discount \n\n total price :{discount}  ")
                else:
                    total_price=base_fee
                    discount=total_price
                    print(f"rantal days is : {days} ")
                    print(f"\ntotal price without discount is : {total_price}")
                    print(f"but you are none membership user so discount \n\n total price  :{discount}  ") 
                
            else:
                print("Please enter valid Optional service.........!") 
    else:
        print(f"please enter valid car type, you have entered : {cartype}")

# if car type is wrong          
else :
    print(f" please enter valid days you have entered : {days} \n            EXIT ")
print("\n\n****************VISIT-AGAIN**********************")
